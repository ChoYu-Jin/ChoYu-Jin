# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.cluster import KMeans

fruits = np.load('fruits_300.npy')
fruits_2d = fruits.reshape(-1, 100*100)

# %%
import matplotlib.pyplot as plt

def draw_fruits(arr, ratio=1):
    n = len(arr)    # n은 샘플 개수입니다
    # 한 줄에 10개씩 이미지를 그립니다. 샘플 개수를 10으로 나누어 전체 행 개수를 계산합니다.
    rows = int(np.ceil(n/10))
    # 행이 1개 이면 열 개수는 샘플 개수입니다. 그렇지 않으면 10개입니다.
    cols = n if rows < 2 else 10
    fig, axs = plt.subplots(rows, cols,
                            figsize=(cols*ratio, rows*ratio), squeeze=False)
    for i in range(rows):
        for j in range(cols):
            if i*10 + j < n:    # n 개까지만 그립니다.
                axs[i, j].imshow(arr[i*10 + j], cmap='gray_r')
            axs[i, j].axis('off')
    plt.show()

# %%
# 주성분 분석
pca = PCA(n_components=30)
pca.fit(fruits_2d)
fruits_pca = pca.transform(fruits_2d)

# %% [markdown]
# # 1. PCA에서 사용한 30개 주성분(component)들의 이미지를 시각화해보세요.

# %%
# 1. 주성분 이미지 시각화

# %% [markdown]
# # 2. 주성분들을 이용하여 원본 데이터를 얼마나 잘 재구성할 수 있는지 확인하기 위해 처음 5개의 주성분을 사용하여 원본 데이터를 재구성하고, 이를 시각화하세요.

# %%
# 2. 주성분을 이용한 원본 데이터 재구성 및 시각화

# %% [markdown]
# # 3. 설명된 분산(explained variance)의 누적 합이 95%가 되도록 필요한 주성분의 수를 확인하세요.

# %%
# 3. 설명된 분산의 누적 합 확인

print(f"Number of components to explain 95% variance: {required_components}")
# Out:
# Number of components to explain 95% variance: 1

# %% [markdown]
# # 4. 다른 알고리즘(로지스틱 회귀)을 사용하여 주성분 전과 후의 성능을 비교하는 코드를 작성하세요. 주성분을 사용하기 전과 후에 각각 로지스틱 회귀의 평균 정확도와 학습 시간을 출력하세요.

# %%
# 4. 다른 알고리즘과 함께 사용하기
lr = LogisticRegression()
# Out:
# Before PCA - Mean Accuracy: 0.9966666666666667
# Before PCA - Mean Fit Time: 0.5650292873382569
# After PCA - Mean Accuracy: 1.0
# After PCA - Mean Fit Time: 0.01078639030456543

# %% [markdown]
# # 5. K-평균 클러스터링을 수행한 결과를 시각화하세요. 클러스터링 결과에 따라 각 과일 이미지를 다른 색상으로 표시하고, 주성분 공간 상에서 각 클러스터의 중심을 나타내는 산점도를 그려보세요.

# %%
# 5. K-평균 클러스터링 결과 시각화
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
